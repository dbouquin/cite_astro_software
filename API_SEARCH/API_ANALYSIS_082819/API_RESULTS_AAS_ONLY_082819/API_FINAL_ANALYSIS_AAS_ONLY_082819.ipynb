# %% [markdown]
# # API Final Analysis
# ### Daina Bouquin, Daniel Chivvis
#
# Scripts below were used to generate all .csv files in the API_RESULTS_AAS_ONLY_082819/ folder

# %%
import pandas as pd
import numpy as np

# %%
API_results = pd.read_csv("API_CLEAN_INPUT_AAS_ONLY_061019.csv")

# %%
list(API_results.columns.values)
# Out:
# ['Alias',
#  'Software_Package',
#  'Identifier',
#  'Highlight',
#  'Citation',
#  'Bibcode',
#  'Alternate_Bibcode',
#  'BibGroup',
#  'Publisher',
#  'Article_ID',
#  'DOI',
#  'Pub_Year',
#  'Pub_Date',
#  'Author',
#  'Title']

# %%
API_results.head(5)
# Out:
#                           Alias Software_Package  Identifier  \
# 0                   astropy.org          Astropy           0
# 1                   astropy.org          Astropy           0
# 2                   astropy.org          Astropy           0
# 3  github.com/astropy/astroplan          Astropy           0
# 4             astropy/astroplan          Astropy           0
#
#                                            Highlight  Citation  \
# 0  http:&#x2F;&#x2F;docs.<em>astropy.org</em> The...     False
# 1  simulation. Halotools is an affiliated package...     False
# 2  and the astropy cosmology package53 53 http:&#...     False
# 3  <em>https:&#x2F;&#x2F;github.com&#x2F;astropy&...     False
# 4  <em>https:&#x2F;&#x2F;github.com&#x2F;astropy&...      True
#
#                Bibcode    Alternate_Bibcode                  BibGroup  \
# 0  2018AJ....155..128M  2017arXiv171209631M                       CfA
# 1  2017AJ....154..190H  2016arXiv160604106H                       CfA
# 2  2017AJ....153..107T  2016arXiv161105456T  NOAO|ESO/Telescopes|CFHT
# 3  2018AJ....155..128M  2017arXiv171209631M                       CfA
# 4  2018AJ....155..128M  2017arXiv171209631M                       CfA
#
#                   Publisher  \
# 0  The Astronomical Journal
# 1  The Astronomical Journal
# 2  The Astronomical Journal
# 3  The Astronomical Journal
# 4  The Astronomical Journal
#
#                                           Article_ID  \
# 0  2017arXiv171209631M|2018AJ....155..128M|10.384...
# 1  2016arXiv160604106H|2017AJ....154..190H|10.384...
# 2  2016arXiv161105456T|2017AJ....153..107T|10.384...
# 3  2017arXiv171209631M|2018AJ....155..128M|10.384...
# 4  2017arXiv171209631M|2018AJ....155..128M|10.384...
#
#                         DOI  Pub_Year    Pub_Date             Author  \
# 0  10.3847/1538-3881/aaa47e      2018  2018-03-00   Morris, Brett M.
# 1  10.3847/1538-3881/aa859f      2017  2017-11-00  Hearin, Andrew P.
# 2  10.3847/1538-3881/aa5b8d      2017  2017-03-00         Tie, S. S.
# 3  10.3847/1538-3881/aaa47e      2018  2018-03-00   Morris, Brett M.
# 4  10.3847/1538-3881/aaa47e      2018  2018-03-00   Morris, Brett M.
#
#                                                Title
# 0  astroplan: An Open Source Observation Planning...
# 1  Forward Modeling of Large-scale Structure: An ...
# 2  A Study of Quasar Selection in the Supernova F...
# 3  astroplan: An Open Source Observation Planning...
# 4  astroplan: An Open Source Observation Planning...

# %%
# Convert highlight col to string

API_results['Highlight'] = API_results['Highlight'].astype('|S')\

# %%
API_results.to_csv("API_FINAL_ANALYSIS_AAS_ONLY_082819.csv")

# %% [markdown]
# ## Summary of Results

# %%
# How many papers did we find for each software package?
API_results.groupby('Software_Package')['Bibcode'].nunique()
# Out:
# Software_Package
# Astroblend        1
# Astropy          93
# RADMC-3D        163
# SAOImage DS9    272
# Spec2d          222
# Stringray         9
# TARDIS            3
# WCSTools        121
# Name: Bibcode, dtype: int64

# %%
# Proportion of articles with a software alias in a citation
API_all_citations = API_results.loc[API_results['Citation'] == True]
API_cite_proportion = API_all_citations.groupby('Software_Package')['Bibcode'].nunique()/API_results.groupby('Software_Package')['Bibcode'].nunique()
API_cite_proportion
# Out:
# Software_Package
# Astroblend           NaN
# Astropy         0.763441
# RADMC-3D        0.803681
# SAOImage DS9    0.411765
# Spec2d          0.527027
# Stringray       0.555556
# TARDIS          0.666667
# WCSTools        0.628099
# Name: Bibcode, dtype: float64

# %%
# How many unique aliases were used in citations for each package?
print (API_all_citations.groupby('Software_Package')['Alias'].nunique())
# Out:
# Software_Package
# Astropy         12
# RADMC-3D         9
# SAOImage DS9    11
# Spec2d          11
# Stringray        2
# TARDIS           2
# WCSTools         9
# Name: Alias, dtype: int64

# %%
# For each package count number of articles that mentioned their identifiers
API_ID_only = API_results.loc[API_results['Identifier'] == 1]
API_ID_only = pd.DataFrame({'count' : API_ID_only.groupby(["Software_Package", "Alias"])['Bibcode'].nunique()})
API_ID_only.to_csv("API_ID_only_AAS_082819.csv")
API_ID_only
# Out:
#                                   count
# Software_Package Alias
# RADMC-3D         ascl:1202.015        1
# Spec2d           arXiv:1203.3192      1
#                  ascl:1203.003        1

# %%
# For each package count number of articles that mentioned their aliases that aren't identifiers
API_non_ID_only = API_results.loc[API_results['Identifier'] == 0]
API_non_ID_only = pd.DataFrame({'count' : API_non_ID_only.groupby(["Software_Package", "Alias"])['Bibcode'].nunique()})
API_non_ID_only.to_csv("API_non_ID_only_AAS_082819.csv")
API_non_ID_only
# Out:
#                                                                      count
# Software_Package Alias
# Astroblend       AstroBlend                                              1
#                  astroblend.com                                          1
# Astropy          AstroPy                                                93
#                  Astropy Collaboration                                  63
#                  Astropy Collaboration 2013                             62
#                  Astropy Collaboration et al. (2013)                    65
#                  Astropy Collaboration et al. (2018)                     1
#                  Astropy Collaboration et al. 2013                      65
#                  Astropy Collaboration et al. 2018                       1
#                  Astropy Collaboration, 2013                            62
#                  astropy.cosmology                                       6
#                  astropy.org                                            18
#                  astropy.units                                           1
#                  astropy/astroplan                                       1
#                  astropy/astroquery                                      1
#                  astropy/astroscrappy                                    2
#                  astropy/halotools                                       1
#                  astropy/photutils                                       1
#                  github.com/astropy                                      7
#                  github.com/astropy/astroplan                            1
#                  github.com/astropy/astroquery                           1
#                  github.com/astropy/astroscrappy                         2
#                  github.com/astropy/halotools                            1
#                  github.com/astropy/photutils                            1
# RADMC-3D         RADMC                                                 134
#                  RADMC-3D                                               85
#                  RADMC3D                                                84
#                  dullemond/software/radmc-3d                            51
#                  ita.uni-heidelberg.de/dullemond/software/radmc-3d      31
#                  ita.uni-heidelberg.de/~dullemond/software/radmc-3d     31
# ...                                                                    ...
# Spec2d           DEEP2 DEIMOS Pipeline                                   6
#                  DEIMOS pipeline                                        16
#                  Spec2d                                                139
#                  The analysis pipeline used to reduce the DEIMOS...      4
#                  astro.berkeley.edu/~cooper/deep/spec2d                 24
#                  astron.berkeley.edu/~cooper/deep/spec2d                12
#                  deep.berkeley.edu/spec2d                                7
#                  deep.ps.uci.edu/spec2d                                  3
#                  idlspec2d                                              63
#                  keck.hawaii.edu/inst/deimos/pipeline.html               5
#                  sdss3.org/svn/repo/idlspec2d                            4
#                  spectro.princeton.edu/idlspec2d                        12
#                  svn.sdss.org/public/repo/manga/mangadrp/tags/v1...      1
# Stringray        HENDRICS                                                2
#                  Stingray                                                8
#                  github.com/StingraySoftware                             1
#                  github.com/StingraySoftware/notebooks                   1
# TARDIS           TARDIS                                                  2
#                  Tardis                                                  1
# WCSTools         WCS Tools                                               2
#                  WCSLIB                                                  2
#                  WCSTools                                              113
#                  harvard.edu/software/wcstools                          19
#                  imwcs                                                  27
#                  sky2xy                                                  3
#                  tdc-www.cfa.harvard.edu/software/wcstools               2
#                  tdc-www.harvard.edu/software/wcstools                   9
#                  tdc-www.harvard.edu/wcstools                           11
#                  wcslib                                                  2
#                  xy2sky                                                 10
#
# [80 rows x 1 columns]

# %%
# total mentions of software aliases over time
API_over_time = pd.DataFrame({'year_count' : API_results.groupby(["Software_Package", "Pub_Year"])['Bibcode'].nunique()}).reset_index()
# write results
API_over_time.to_csv("API_over_time_AAS_ONLY_082819.csv")
# show results over time
API_over_time
# Out:
#    Software_Package  Pub_Year  year_count
# 0        Astroblend      2016           1
# 1           Astropy      2013           1
# 2           Astropy      2014           6
# 3           Astropy      2015           6
# 4           Astropy      2016          27
# 5           Astropy      2017          36
# 6           Astropy      2018          17
# 7          RADMC-3D      2004           1
# 8          RADMC-3D      2005           1
# 9          RADMC-3D      2006           1
# 10         RADMC-3D      2007           4
# 11         RADMC-3D      2008           4
# 12         RADMC-3D      2009           9
# 13         RADMC-3D      2010          12
# 14         RADMC-3D      2011           6
# 15         RADMC-3D      2012          12
# 16         RADMC-3D      2013          11
# 17         RADMC-3D      2014          11
# 18         RADMC-3D      2015          24
# 19         RADMC-3D      2016          25
# 20         RADMC-3D      2017          33
# 21         RADMC-3D      2018           9
# 22     SAOImage DS9      1997           2
# 23     SAOImage DS9      1998           3
# 24     SAOImage DS9      1999           1
# 25     SAOImage DS9      2000           2
# 26     SAOImage DS9      2001           4
# 27     SAOImage DS9      2002           3
# 28     SAOImage DS9      2003           4
# 29     SAOImage DS9      2004           6
# ..              ...       ...         ...
# 60           Spec2d      2018           5
# 61        Stringray      1999           2
# 62        Stringray      2000           1
# 63        Stringray      2001           1
# 64        Stringray      2015           1
# 65        Stringray      2017           2
# 66        Stringray      2018           2
# 67           TARDIS      2002           1
# 68           TARDIS      2016           1
# 69           TARDIS      2017           1
# 70         WCSTools      1998           1
# 71         WCSTools      1999           1
# 72         WCSTools      2001           3
# 73         WCSTools      2002           5
# 74         WCSTools      2003           4
# 75         WCSTools      2004           6
# 76         WCSTools      2005           5
# 77         WCSTools      2006           5
# 78         WCSTools      2007           9
# 79         WCSTools      2008           3
# 80         WCSTools      2009           7
# 81         WCSTools      2010          20
# 82         WCSTools      2011          12
# 83         WCSTools      2012          12
# 84         WCSTools      2013           9
# 85         WCSTools      2014           3
# 86         WCSTools      2015           6
# 87         WCSTools      2016           3
# 88         WCSTools      2017           6
# 89         WCSTools      2018           1
#
# [90 rows x 3 columns]

# %%
#Alias per paper

API_alias_paper = pd.DataFrame(API_results.groupby(['Software_Package','DOI'])['Alias'].nunique())
API_alias_paper.to_csv("API_alias_paper_AAS_ONLY_082819.csv")
API_alias_paper
# Out:
#                                               Alias
# Software_Package DOI
# Astroblend       10.3847/0004-637X/818/2/115      2
# Astropy          10.1088/0004-637X/784/2/137      6
#                  10.1088/0004-637X/798/1/24       7
#                  10.1088/0004-637X/806/2/260      6
#                  10.1088/0004-637X/814/2/108      1
#                  10.1088/0004-637X/815/1/4        6
#                  10.1088/0004-637X/815/1/77       6
#                  10.1088/0067-0049/219/1/14       7
#                  10.1088/2041-8205/776/2/L34      4
#                  10.1088/2041-8205/780/1/L13      6
#                  10.1088/2041-8205/782/2/L17      6
#                  10.1088/2041-8205/783/1/L23      7
#                  10.1088/2041-8205/787/1/L5       6
#                  10.1088/2041-8205/788/2/L34      6
#                  10.3847/0004-637X/822/1/47       4
#                  10.3847/0004-637X/822/2/97       2
#                  10.3847/0004-637X/823/1/50       6
#                  10.3847/0004-637X/823/1/57       7
#                  10.3847/0004-637X/824/1/52       1
#                  10.3847/0004-637X/824/2/104      1
#                  10.3847/0004-637X/824/2/83       7
#                  10.3847/0004-637X/825/1/82       6
#                  10.3847/0004-637X/825/2/142      2
#                  10.3847/0004-637X/826/2/191      1
#                  10.3847/0004-637X/827/1/12       7
#                  10.3847/0004-637X/827/1/59       6
#                  10.3847/0004-637X/828/1/21       6
#                  10.3847/0004-637X/828/1/40       6
#                  10.3847/0004-637X/830/1/36       7
#                  10.3847/0004-637X/832/1/43       6
# ...                                             ...
# WCSTools         10.1088/0004-637X/778/1/19       1
#                  10.1088/0004-637X/778/2/91       1
#                  10.1088/0004-637X/779/1/42       2
#                  10.1088/0004-637X/787/1/55       1
#                  10.1088/0004-637X/789/2/138      1
#                  10.1088/0004-637X/809/1/17       1
#                  10.1088/0004-637X/815/2/120      3
#                  10.1088/0067-0049/184/1/172      2
#                  10.1088/0067-0049/185/1/85       1
#                  10.1088/0067-0049/188/1/75       1
#                  10.1088/0067-0049/188/2/488      1
#                  10.1088/0067-0049/193/1/12       1
#                  10.1088/0067-0049/193/2/26       4
#                  10.1088/0067-0049/193/2/28       4
#                  10.1088/0067-0049/203/1/2        2
#                  10.1088/0067-0049/218/2/29       1
#                  10.1088/2041-8205/746/1/L11      2
#                  10.1088/2041-8205/749/1/L2       1
#                  10.1088/2041-8205/765/1/L19      2
#                  10.1088/2041-8205/807/1/L2       1
#                  10.3847/0004-637X/818/1/67       1
#                  10.3847/0004-637X/825/2/151      2
#                  10.3847/0067-0049/225/1/11       1
#                  10.3847/1538-3881/aa63f1         1
#                  10.3847/1538-3881/aa89ef         1
#                  10.3847/1538-4357/aa607e         2
#                  10.3847/1538-4357/aa6983         1
#                  10.3847/1538-4357/aa844d         1
#                  10.3847/1538-4357/aa93f0         1
#                  10.3847/1538-4357/aab35b         1
#
# [884 rows x 1 columns]

# %%
# Software citations per paper

API_alias_citations = pd.DataFrame(API_results.groupby(['Software_Package','Citation'])['Bibcode'].nunique())
API_alias_citations.to_csv("API_alias_citations_AAS_ONLY_082819.csv")
API_alias_citations
# Out:
#                            Bibcode
# Software_Package Citation
# Astroblend       False           1
# Astropy          False          30
#                  True           71
# RADMC-3D         False          55
#                  True          131
# SAOImage DS9     False         168
#                  True          112
# Spec2d           False         123
#                  True          117
# Stringray        False           5
#                  True            5
# TARDIS           False           1
#                  True            2
# WCSTools         False          55
#                  True           76
